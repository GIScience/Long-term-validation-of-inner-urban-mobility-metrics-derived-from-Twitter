# %%
import community
import statistics
import numpy as np
import pandas as pd
import networkx as nx
import geopandas as gpd
from community import community_louvain
import notebooks_loops_script as nls

# %% [markdown]
# # Calculating OD-matrix based mobility indictors
# Using the OD-Matrices calculated in Notebook B_02, further metrics are calculated here.

# %%
# Rolling Window Parameters
start = "20200406"
end = "20200409"
denom = "3days"
allow_even_subsets = False
sam = False
del_one_tweeters = True

# %%
ref = "statistics_notebookdemo/" + denom + "_overlap.csv"
if type(sam) == int:
    ref = ref.split('.csv')[0] + "_" +str(sam) + ".csv"

# %%
path = f"data/{ref}"
file = pd.read_csv(f'data/{ref}', index_col='start_date')

# %%
middle = nls.middeling(start, end, allow_even_subsets=allow_even_subsets)
mm_path = f'./data/movement_matrices_notebookdemo/{denom}/mm_{middle}.npy'

# %% [markdown]
# ### Load in Shapefiles

# %%
barrios_path = 'data/shps/neighborhoods.shp'
barrios_20823 = gpd.read_file(barrios_path).to_crs(20823)

barrios_20823.CODBAIRRO = barrios_20823.CODBAIRRO.astype(int)
barrios_20823['geometry'] = barrios_20823.geometry.representative_point()# oder representative_point?
barrios_20823['lat'] = barrios_20823['geometry'].y
barrios_20823['lon'] = barrios_20823['geometry'].x

# %%
stats = {}

# %% [markdown]
# ### Load in Movement Matrices
# Here, one movement matrix (or OD-Matrix) is loaded. In the notebook_loops_script.py all relevant matrices are loaded and processed via a loop.

# %%
mm = np.load(mm_path)

# %%
# set diagonal, if the workflow from before was executed as intended, there should be no values on teh diagonal anyway.
for i in range(mm.shape[0]):
    mm[i,i] = 0
        
mm_normal = mm / mm.sum()

# %%
# The amount of registered movements can be determined by the total sum of the OD matrix
stats['no_real_movements'] = mm.sum().sum()

# %% [markdown]
# ### Graph based modularity
# Caluclaute the Graph Modularity based on the community louvain package. If no graph can be constructed (that happens at some rolling windows with very few tweets) the value gets an np.nan

# %%
G = nx.from_numpy_array(mm)
partition = community_louvain.best_partition(G, weight='weight')

try:
    stats['graph_modularity'] = community.modularity(partition, G)
except:
    print("Undefined Modularity!")
    stats['graph_modularity'] = np.nan

# %%
stats
# Out:
# {'no_real_movements': 45.0, 'graph_modularity': 0.799375}

# %% [markdown]
# ### Inflow / Outflow per Barrio
# For each neighborhood, the inflow and outflow values get counted and saved.

# %%
inflow = {}
outflow = {}
for i in range(mm.shape[0]): # y/rows
    outflow['outflow_' + str(i+1) + '_barrio'] = mm[i, :].sum()

for i in range(mm.shape[1]): # x/cols
    inflow['inflow_' + str(i+1) + '_barrio'] = mm[:, i].sum()

stats.update(inflow)
stats.update(outflow)

# %% [markdown]
# ### Mean \# of Meaningful Connections (>= 5 %)
# Based on outgoing values, we calculate for each barrio the number of meaningful connections that make up 5 % or more of all outgoing connections. The mean of this number is saved.

# %%
# Barrios with no outgoing/incoming connections will be ignored connections
# [row, column]
def number_of_meaningful_connections(outflow=False):
    numbers_of_meaningful_connections = []
    
    for i in range(mm.shape[0]):
        rel = mm[i, :]
        if outflow:
            rel = mm[:, i]
    
        outgoing_sum = rel.sum()
        
        # if we dont have any connections, continue -> ignore these barrios
        if outgoing_sum == 0:
            continue

        outgoing_rel = rel / outgoing_sum
        count = len(outgoing_rel[outgoing_rel >= 0.05])

        numbers_of_meaningful_connections.append(count)
    
    return statistics.mean(numbers_of_meaningful_connections)
    
    
stats['number_meaningful_incoming'] = number_of_meaningful_connections()
stats['number_meaningful_outgoing'] = number_of_meaningful_connections(outflow=True)

# %% [markdown]
# ### Mean Distance to highest connection
# We calculate for each barrio the strongest partner and than the distances between its representatve points. The we calculate the mean between all barrios.

# %%
def get_mean_distance_to_highest(outflow=False):
    all_distances = []
    for i in range(mm.shape[0]):
        # list, in case it's multiple barrios
        distances = []

        rel = mm[i, :]
        if outflow:
            rel = mm[:, i]

        # if we dont have any connections, continue -> ignore these barrios
        if sum(rel) == 0:
            continue

        l = []
        l.extend(list(np.where(rel == max(rel))[0]))

        for partner in l:
            partner += 1
            og = barrios_20823.loc[barrios_20823.CODBAIRRO == i+1].geometry.values[0]
            comp = barrios_20823.loc[barrios_20823.CODBAIRRO == partner].geometry.values[0]
            distances.append(og.distance(comp))

        #print(distances)
        all_distances.append(statistics.mean(distances))

    return statistics.mean(all_distances)

stats['mean_distance_strongest_inflow'] = get_mean_distance_to_highest(outflow=False)
stats['mean_distance_strongest_outflow'] = get_mean_distance_to_highest(outflow=True)

# %%
start = int(start)
for name, val in stats.items():
    file.loc[start, name] = val
    
file.to_csv(f'data/{ref}')

# %%
for key, val in stats.items():
    print(key, ":", val)
# Out:
# no_real_movements : 45.0
# graph_modularity : 0.799375
# inflow_1_barrio : 0.0
# inflow_2_barrio : 0.0
# inflow_3_barrio : 0.0
# inflow_4_barrio : 0.0
# inflow_5_barrio : 3.0
# inflow_6_barrio : 0.0
# inflow_7_barrio : 0.0
# inflow_8_barrio : 0.0
# inflow_9_barrio : 0.0
# inflow_10_barrio : 0.0
# inflow_11_barrio : 0.0
# inflow_12_barrio : 1.0
# inflow_13_barrio : 0.0
# inflow_14_barrio : 0.0
# inflow_15_barrio : 0.0
# inflow_16_barrio : 0.0
# inflow_17_barrio : 0.0
# inflow_18_barrio : 0.0
# inflow_19_barrio : 0.0
# inflow_20_barrio : 0.0
# inflow_21_barrio : 0.0
# inflow_22_barrio : 1.0
# inflow_23_barrio : 0.0
# inflow_24_barrio : 0.0
# inflow_25_barrio : 1.0
# inflow_26_barrio : 0.0
# inflow_27_barrio : 0.0
# inflow_28_barrio : 0.0
# inflow_29_barrio : 0.0
# inflow_30_barrio : 0.0
# inflow_31_barrio : 0.0
# inflow_32_barrio : 0.0
# inflow_33_barrio : 0.0
# inflow_34_barrio : 0.0
# inflow_35_barrio : 1.0
# inflow_36_barrio : 0.0
# inflow_37_barrio : 0.0
# inflow_38_barrio : 2.0
# inflow_39_barrio : 1.0
# inflow_40_barrio : 0.0
# inflow_41_barrio : 0.0
# inflow_42_barrio : 0.0
# inflow_43_barrio : 1.0
# inflow_44_barrio : 0.0
# inflow_45_barrio : 0.0
# inflow_46_barrio : 0.0
# inflow_47_barrio : 0.0
# inflow_48_barrio : 0.0
# inflow_49_barrio : 1.0
# inflow_50_barrio : 0.0
# inflow_51_barrio : 2.0
# inflow_52_barrio : 0.0
# inflow_53_barrio : 0.0
# inflow_54_barrio : 0.0
# inflow_55_barrio : 0.0
# inflow_56_barrio : 1.0
# inflow_57_barrio : 0.0
# inflow_58_barrio : 0.0
# inflow_59_barrio : 0.0
# inflow_60_barrio : 0.0
# inflow_61_barrio : 2.0
# inflow_62_barrio : 0.0
# inflow_63_barrio : 0.0
# inflow_64_barrio : 0.0
# inflow_65_barrio : 1.0
# inflow_66_barrio : 1.0
# inflow_67_barrio : 0.0
# inflow_68_barrio : 0.0
# inflow_69_barrio : 0.0
# inflow_70_barrio : 0.0
# inflow_71_barrio : 0.0
# inflow_72_barrio : 0.0
# inflow_73_barrio : 0.0
# inflow_74_barrio : 0.0
# inflow_75_barrio : 1.0
# inflow_76_barrio : 0.0
# inflow_77_barrio : 0.0
# inflow_78_barrio : 0.0
# inflow_79_barrio : 0.0
# inflow_80_barrio : 0.0
# inflow_81_barrio : 0.0
# inflow_82_barrio : 0.0
# inflow_83_barrio : 3.0
# inflow_84_barrio : 0.0
# inflow_85_barrio : 0.0
# inflow_86_barrio : 0.0
# inflow_87_barrio : 1.0
# inflow_88_barrio : 1.0
# inflow_89_barrio : 0.0
# inflow_90_barrio : 0.0
# inflow_91_barrio : 0.0
# inflow_92_barrio : 0.0
# inflow_93_barrio : 0.0
# inflow_94_barrio : 0.0
# inflow_95_barrio : 0.0
# inflow_96_barrio : 0.0
# inflow_97_barrio : 0.0
# inflow_98_barrio : 0.0
# inflow_99_barrio : 0.0
# inflow_100_barrio : 0.0
# inflow_101_barrio : 0.0
# inflow_102_barrio : 0.0
# inflow_103_barrio : 0.0
# inflow_104_barrio : 0.0
# inflow_105_barrio : 0.0
# inflow_106_barrio : 0.0
# inflow_107_barrio : 0.0
# inflow_108_barrio : 0.0
# inflow_109_barrio : 1.0
# inflow_110_barrio : 0.0
# inflow_111_barrio : 0.0
# inflow_112_barrio : 0.0
# inflow_113_barrio : 0.0
# inflow_114_barrio : 1.0
# inflow_115_barrio : 0.0
# inflow_116_barrio : 0.0
# inflow_117_barrio : 0.0
# inflow_118_barrio : 0.0
# inflow_119_barrio : 0.0
# inflow_120_barrio : 0.0
# inflow_121_barrio : 0.0
# inflow_122_barrio : 0.0
# inflow_123_barrio : 0.0
# inflow_124_barrio : 1.0
# inflow_125_barrio : 0.0
# inflow_126_barrio : 0.0
# inflow_127_barrio : 0.0
# inflow_128_barrio : 0.0
# inflow_129_barrio : 0.0
# inflow_130_barrio : 0.0
# inflow_131_barrio : 0.0
# inflow_132_barrio : 3.0
# inflow_133_barrio : 1.0
# inflow_134_barrio : 0.0
# inflow_135_barrio : 0.0
# inflow_136_barrio : 0.0
# inflow_137_barrio : 0.0
# inflow_138_barrio : 0.0
# inflow_139_barrio : 0.0
# inflow_140_barrio : 0.0
# inflow_141_barrio : 2.0
# inflow_142_barrio : 0.0
# inflow_143_barrio : 0.0
# inflow_144_barrio : 1.0
# inflow_145_barrio : 0.0
# inflow_146_barrio : 0.0
# inflow_147_barrio : 1.0
# inflow_148_barrio : 1.0
# inflow_149_barrio : 2.0
# inflow_150_barrio : 0.0
# inflow_151_barrio : 1.0
# inflow_152_barrio : 0.0
# inflow_153_barrio : 0.0
# inflow_154_barrio : 1.0
# inflow_155_barrio : 0.0
# inflow_156_barrio : 0.0
# inflow_157_barrio : 2.0
# inflow_158_barrio : 0.0
# inflow_159_barrio : 0.0
# inflow_160_barrio : 0.0
# inflow_161_barrio : 2.0
# inflow_162_barrio : 0.0
# inflow_163_barrio : 0.0
# outflow_1_barrio : 0.0
# outflow_2_barrio : 0.0
# outflow_3_barrio : 0.0
# outflow_4_barrio : 0.0
# outflow_5_barrio : 4.0
# outflow_6_barrio : 0.0
# outflow_7_barrio : 0.0
# outflow_8_barrio : 0.0
# outflow_9_barrio : 0.0
# outflow_10_barrio : 0.0
# outflow_11_barrio : 0.0
# outflow_12_barrio : 0.0
# outflow_13_barrio : 0.0
# outflow_14_barrio : 0.0
# outflow_15_barrio : 0.0
# outflow_16_barrio : 0.0
# outflow_17_barrio : 1.0
# outflow_18_barrio : 0.0
# outflow_19_barrio : 0.0
# outflow_20_barrio : 0.0
# outflow_21_barrio : 0.0
# outflow_22_barrio : 0.0
# outflow_23_barrio : 1.0
# outflow_24_barrio : 1.0
# outflow_25_barrio : 2.0
# outflow_26_barrio : 0.0
# outflow_27_barrio : 0.0
# outflow_28_barrio : 0.0
# outflow_29_barrio : 0.0
# outflow_30_barrio : 0.0
# outflow_31_barrio : 1.0
# outflow_32_barrio : 0.0
# outflow_33_barrio : 0.0
# outflow_34_barrio : 0.0
# outflow_35_barrio : 1.0
# outflow_36_barrio : 0.0
# outflow_37_barrio : 0.0
# outflow_38_barrio : 1.0
# outflow_39_barrio : 0.0
# outflow_40_barrio : 0.0
# outflow_41_barrio : 0.0
# outflow_42_barrio : 0.0
# outflow_43_barrio : 1.0
# outflow_44_barrio : 0.0
# outflow_45_barrio : 2.0
# outflow_46_barrio : 0.0
# outflow_47_barrio : 0.0
# outflow_48_barrio : 0.0
# outflow_49_barrio : 0.0
# outflow_50_barrio : 0.0
# outflow_51_barrio : 3.0
# outflow_52_barrio : 0.0
# outflow_53_barrio : 0.0
# outflow_54_barrio : 0.0
# outflow_55_barrio : 0.0
# outflow_56_barrio : 0.0
# outflow_57_barrio : 0.0
# outflow_58_barrio : 0.0
# outflow_59_barrio : 0.0
# outflow_60_barrio : 0.0
# outflow_61_barrio : 2.0
# outflow_62_barrio : 0.0
# outflow_63_barrio : 0.0
# outflow_64_barrio : 0.0
# outflow_65_barrio : 0.0
# outflow_66_barrio : 2.0
# outflow_67_barrio : 0.0
# outflow_68_barrio : 0.0
# outflow_69_barrio : 0.0
# outflow_70_barrio : 0.0
# outflow_71_barrio : 0.0
# outflow_72_barrio : 0.0
# outflow_73_barrio : 0.0
# outflow_74_barrio : 0.0
# outflow_75_barrio : 0.0
# outflow_76_barrio : 0.0
# outflow_77_barrio : 0.0
# outflow_78_barrio : 0.0
# outflow_79_barrio : 0.0
# outflow_80_barrio : 0.0
# outflow_81_barrio : 0.0
# outflow_82_barrio : 0.0
# outflow_83_barrio : 1.0
# outflow_84_barrio : 0.0
# outflow_85_barrio : 0.0
# outflow_86_barrio : 0.0
# outflow_87_barrio : 0.0
# outflow_88_barrio : 1.0
# outflow_89_barrio : 0.0
# outflow_90_barrio : 1.0
# outflow_91_barrio : 0.0
# outflow_92_barrio : 0.0
# outflow_93_barrio : 0.0
# outflow_94_barrio : 0.0
# outflow_95_barrio : 0.0
# outflow_96_barrio : 0.0
# outflow_97_barrio : 0.0
# outflow_98_barrio : 0.0
# outflow_99_barrio : 0.0
# outflow_100_barrio : 0.0
# outflow_101_barrio : 0.0
# outflow_102_barrio : 0.0
# outflow_103_barrio : 0.0
# outflow_104_barrio : 0.0
# outflow_105_barrio : 0.0
# outflow_106_barrio : 0.0
# outflow_107_barrio : 0.0
# outflow_108_barrio : 0.0
# outflow_109_barrio : 0.0
# outflow_110_barrio : 1.0
# outflow_111_barrio : 0.0
# outflow_112_barrio : 0.0
# outflow_113_barrio : 1.0
# outflow_114_barrio : 1.0
# outflow_115_barrio : 0.0
# outflow_116_barrio : 0.0
# outflow_117_barrio : 1.0
# outflow_118_barrio : 0.0
# outflow_119_barrio : 0.0
# outflow_120_barrio : 0.0
# outflow_121_barrio : 0.0
# outflow_122_barrio : 0.0
# outflow_123_barrio : 0.0
# outflow_124_barrio : 0.0
# outflow_125_barrio : 0.0
# outflow_126_barrio : 0.0
# outflow_127_barrio : 0.0
# outflow_128_barrio : 0.0
# outflow_129_barrio : 0.0
# outflow_130_barrio : 0.0
# outflow_131_barrio : 0.0
# outflow_132_barrio : 3.0
# outflow_133_barrio : 2.0
# outflow_134_barrio : 0.0
# outflow_135_barrio : 0.0
# outflow_136_barrio : 0.0
# outflow_137_barrio : 0.0
# outflow_138_barrio : 0.0
# outflow_139_barrio : 0.0
# outflow_140_barrio : 0.0
# outflow_141_barrio : 1.0
# outflow_142_barrio : 0.0
# outflow_143_barrio : 0.0
# outflow_144_barrio : 2.0
# outflow_145_barrio : 0.0
# outflow_146_barrio : 0.0
# outflow_147_barrio : 2.0
# outflow_148_barrio : 0.0
# outflow_149_barrio : 2.0
# outflow_150_barrio : 0.0
# outflow_151_barrio : 0.0
# outflow_152_barrio : 0.0
# outflow_153_barrio : 0.0
# outflow_154_barrio : 0.0
# outflow_155_barrio : 1.0
# outflow_156_barrio : 0.0
# outflow_157_barrio : 2.0
# outflow_158_barrio : 0.0
# outflow_159_barrio : 0.0
# outflow_160_barrio : 0.0
# outflow_161_barrio : 0.0
# outflow_162_barrio : 1.0
# outflow_163_barrio : 0.0
# number_meaningful_incoming : 1.4137931034482758
# number_meaningful_outgoing : 1.28125
# mean_distance_strongest_inflow : 10971.916376811465
# mean_distance_strongest_outflow : 10590.6470769989
